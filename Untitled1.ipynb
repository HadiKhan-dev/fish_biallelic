# %%
import sys
# !{sys.executable} main.py
# Out:
# Main process (86506) niceness set to: 0
#
# ...
# PROCESSING REGION: (chr7 blocks 0-3000)
# ...
#   [Loader] Loaded 1397 blocks in 3.46s
#   [Discovery] Haplotypes generated in 2140.70s
#   [Naive Linker] Chained 6 haps in 9.30s
#
# All regions processed in 2153.46s
# Running Multi-Contig Simulation for 1 regions...
# Normal mode: Using mutation rate 1e-10 (minimal mutations)
# Detected Multi-Contig Simulation (1 contigs).
# Simulating F1: 20 individuals...
# Simulating F2: 100 individuals...
# Simulating F3: 200 individuals...
# Pedigree simulation completed in 8.8s
# Ground Truth Pedigree data saved to 'results_simulation/ground_truth_pedigree.csv'
#
# Processing Simulated Data for Region: chr7
# Error: Matplotlib/Seaborn not installed.
#
# Simulation, Sequencing, and Chunking complete for all regions.
# Total time: 78.6s
#
# ...
# Discovering Block Haplotypes from Simulated Reads
# ...
#
#   Processing chr7...
#     2737 blocks, haps/block: min=1, max=7, mean=4.6
#
# ...
