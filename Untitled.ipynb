# %%
import sys
# !{sys.executable} main.py
# Out:
# Traceback (most recent call last):
#   File "/rds/project/rds-8b3VcZwY7rY/projects/haplotype_reconstruction/main.py", line 31, in <module>
#     import hmm_matching
#   File "/rds/project/rds-8b3VcZwY7rY/projects/haplotype_reconstruction/hmm_matching.py", line 9, in <module>
#     import block_linking_em
# ModuleNotFoundError: No module named 'block_linking_em'
